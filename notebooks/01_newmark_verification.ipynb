# %% [markdown]
# # 01 — Newmark Solver Verification
#
# Verify the Newmark constant average acceleration solver against:
# - Analytical solution for a 1-DOF system
# - Modal analysis natural frequencies
# - Energy conservation check

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
from src.structures import ShearBuilding, NewmarkSolver, modal_analysis

# %%
# TODO: Implement verification tests
