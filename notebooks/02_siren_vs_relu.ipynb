# %% [markdown]
# # 02 — SIREN vs ReLU: Spectral Bias Demonstration
#
# Compare SIREN and ReLU networks fitting an oscillatory signal.
# Demonstrates why sin activations are critical for vibration data.

# %%
import sys
sys.path.insert(0, '..')

import torch
import numpy as np
import matplotlib.pyplot as plt
from src.pinn.siren import SirenNet

# %%
# TODO: Implement SIREN vs ReLU comparison
