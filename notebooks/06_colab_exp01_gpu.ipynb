# %% [markdown]
# # Colab GPU Run: Experiment 01
#
# This notebook runs `experiments/exp01_clean_data.py` on Google Colab with GPU acceleration.
#
# 1. In Colab, set **Runtime -> Change runtime type -> Hardware accelerator = GPU**.
# 2. Set `REPO_URL` to your GitHub repository URL.
# 3. Run cells in order.

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/thlgrs/Vibration_PINN.git"  # <- update this
PROJECT_DIR = Path("/content/Vibration_PINN")

if not PROJECT_DIR.exists():
    if "YOUR-ORG" in REPO_URL:
        raise ValueError("Set REPO_URL to your real GitHub repo first.")
    subprocess.check_call(["git", "clone", REPO_URL, str(PROJECT_DIR)])

os.chdir(PROJECT_DIR)
print(f"Working directory: {Path.cwd()}")
# Out:
# Working directory: /content/Vibration_PINN

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !python -m pip install --quiet --upgrade pip
# !python -m pip install --quiet -r requirements-colab.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements-colab.txt'

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.10.0+cpu
# CUDA available: False

# %% [markdown]
# ## Quick Smoke Run
#
# Runs only a few epochs to verify the pipeline quickly.

# %%
# !python experiments/exp01_clean_data.py --phase1-epochs 30 --phase2-epochs 120 --hidden-features 64 --hidden-layers 3
# Out:
# Using device: cpu
#
# === Identified Parameters ===
# Masses:      [5460.034  5411.1255 5441.8135]
# True masses: [5000. 5000. 5000.]
# Stiffnesses: [9064813.  6941258.  4705486.5]
# True stiff.: [8000000. 6000000. 4000000.]
# Damping:     0.1417
# True damp.:  0.05
# Saved plots:
# - /content/Vibration_PINN/results/parameter_convergence/exp01_loss.png
# - /content/Vibration_PINN/results/parameter_convergence/exp01_stiffness.png

# %% [markdown]
# ## Full Baseline Run
#
# Use this after the smoke run succeeds.

# %%
# !python experiments/exp01_clean_data.py --phase1-epochs 500 --phase2-epochs 3000
# Out:
# Using device: cpu
# Traceback (most recent call last):
#   File "/content/Vibration_PINN/experiments/exp01_clean_data.py", line 155, in <module>
#     main()
#   File "/content/Vibration_PINN/experiments/exp01_clean_data.py", line 125, in main
#     history = trainer.train()
#               ^^^^^^^^^^^^^^^
#   File "/content/Vibration_PINN/src/pinn/trainer.py", line 190, in train
#     self.train_phase2()
#   File "/content/Vibration_PINN/src/pinn/trainer.py", line 176, in train_phase2
#     loss.backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 630, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 364, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 865, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !ls -lah results/parameter_convergence
# Out:
# total 8.0K
# drwxr-xr-x 2 root root 4.0K Feb 25 10:39 .
# drwxr-xr-x 6 root root 4.0K Feb 25 10:39 ..
# -rw-r--r-- 1 root root    0 Feb 25 10:39 .gitkeep
